# %%
# %load_ext autoreload
# %autoreload 2

import erdantic as erd
from app import models
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
erd.create(models.Solution)
# Out:
# EntityRelationshipDiagram(models=[PydanticModel(Chain), PydanticModel(Action), PydanticModel(ActionType), PydanticModel(Environment), PydanticModel(Node), PydanticModel(Experiment), PydanticModel(Treatment), PydanticModel(Game), PydanticModel(Solution), PydanticModel(Stage), PydanticModel(Step), PydanticModel(User)], edges=[Edge(source=PydanticModel(Chain), source_field=<PydanticField: 'experiment_id', Experiment>, target=PydanticModel(Experiment)), Edge(source=PydanticModel(Chain), source_field=<PydanticField: 'treatment_name', Treatment>, target=PydanticModel(Treatment)), Edge(source=PydanticModel(Chain), source_field=<PydanticField: 'environment_ids', List[Environment]>, target=PydanticModel(Environment)), Edge(source=PydanticModel(Environment), source_field=<PydanticField: 'nodes', List[Node]>, target=PydanticModel(Node)), Edge(source=PydanticModel(Environment), source_field=<PydanticField: 'actions', List[Action]>, target=PydanticModel(Action)), Edge(source=PydanticModel(Environ
# ...
